# %% [markdown]
# # Exploratory Data Analysis Process on Social Media Sentimental Dataset
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the Dataset

# %%
data = pd.read_csv('/content/sentimentdataset.csv')
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
data.shape
# Out:
# (732, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
data.dtypes
# Out:
# Unnamed: 0.1      int64
# Unnamed: 0        int64
# Text             object
# Sentiment        object
# Timestamp        object
# User             object
# Platform         object
# Hashtags         object
# Retweets        float64
# Likes           float64
# Country          object
# Year              int64
# Month             int64
# Day               int64
# Hour              int64
# dtype: object

# %% [markdown]
# ### Handling with missing values

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %% [markdown]
# ### Statistics Summary

# %%
data.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %% [markdown]
# ### Data Cleaning and Manipulation

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# Droping the unnecessary columns
data.drop(columns={'Unnamed: 0.1'},inplace=True)

# %%
# Renameing the column
data.rename(columns={'Unnamed: 0' : 'Id'},inplace=True)

# %%
data['Platform'] = data['Platform'].str.replace("whatsapp", "whatsapp",0)

# %%
data['Platform'].value_counts()
# Out:
# Platform
# Instagram     258
# Facebook      231
# whatsapp      128
# whatsapp      115
# Name: count, dtype: int64

# %% [markdown]
# ### Data Analysis and Visualization

# %%
data['Platform'].value_counts(normalize=True).plot.pie(title= 'Platform wise Distribution',autopct='%1.1f%%',figsize=(8, 5))
plt.show()

# %%
sns.kdeplot(data=data, x='Likes', hue='Platform', fill=True)
plt.title('Platform wise Likes Distribution')
plt.show()

# %%
sns.kdeplot(data=data, x='Retweets',hue='Platform',fill=True)
plt.title('Platform wise Retweets Distribution')
plt.show()

# %%
sns.scatterplot(x='Likes', y='Retweets', data=data,hue='Platform')
plt.title('Likes v/s Retweets')
plt.show()

# %%
data['Country'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Tweeting Countries")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data, x = 'Year',hue='Platform')
plt.title("Tweet Count Per Year")
# Out:
# Text(0.5, 1.0, 'Tweet Count Per Year')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data, x = 'Month',hue='Platform')
plt.title("Monthly Trends")
plt.show()
